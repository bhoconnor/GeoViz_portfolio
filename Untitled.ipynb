# %%
import geopandas as gpd

# %%
study = gpd.read_file(/Users/bhoconnor/Library/CloudStorage/GoogleDrive-boconn17@charlotte.edu/My Drive/4. Coursework/2026a - Spring/1. GEOG 8005 - Open-Source Viz./data/fromFall2025proj/3homes.json") #circles for 3 homes
vec = gpd.read_file("/Users/bhoconnor/Library/CloudStorage/GoogleDrive-boconn17@charlotte.edu/My Drive/4. Coursework/2026a - Spring/1. GEOG 8005 - Open-Source Viz./data/fromFall2025proj/polygon_Concord_neighborhood_2017-2021.json") #block groups
# Out:
#   Cell In[2], line 1
#     study = gpd.read_file(/Users/bhoconnor/Library/CloudStorage/GoogleDrive-boconn17@charlotte.edu/My Drive/4. Coursework/2026a - Spring/1. GEOG 8005 - Open-Source Viz./data/fromFall2025proj/3homes.json") #circles for 3 homes
#                                                                                                                              ^
# SyntaxError: invalid decimal literal

# %%
study = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/3homes.json") #circles for 3 homes
vec = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/polygon_Concord_neighborhood_2017-2021.json") #block groups
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 study = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/3homes.json") #circles for 3 homes
#       2 vec = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/polygon_Concord_neighborhood_2017-2021.json")
#
# File /opt/miniconda3/envs/geovis/lib/python3.11/site-packages/geopandas/io/file.py:140, in _read_file(filename, bbox, mask, rows, **kwargs)
#     135     reader = fiona.BytesCollection
#     136 else:
#     137     # Opening a file via URL or file-like-object above automatically detects a
#     138     # zipped file. In order to match that behavior, attempt to add a zip scheme
#     139     # if missing.
# --> 140     if _is_zip(str(filename)):
#     141         parsed = fiona.parse_path(str(filename))
#     142         if isinstance(parsed, fiona.path.ParsedPath):
# ...

# %%
vec = gpd.read_file("/Users/bhoconnor/Library/CloudStorage/GoogleDrive-boconn17@charlotte.edu/My Drive/4. Coursework/2026a - Spring/1. GEOG 8005 - Open-Source Viz./data/fromFall2025proj/polygon_Concord_neighborhood_2017-2021.json") #block groups
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 vec = gpd.read_file("/Users/bhoconnor/Library/CloudStorage/GoogleDrive-boconn17@charlotte.edu/My Drive/4. Coursework/2026a - Spring/1. GEOG 8005 - Open-Source Viz./data/fromFall2025proj/polygon_Concord_neighborhood_2017-2021.json")
#
# File /opt/miniconda3/envs/geovis/lib/python3.11/site-packages/geopandas/io/file.py:140, in _read_file(filename, bbox, mask, rows, **kwargs)
#     135     reader = fiona.BytesCollection
#     136 else:
#     137     # Opening a file via URL or file-like-object above automatically detects a
#     138     # zipped file. In order to match that behavior, attempt to add a zip scheme
#     139     # if missing.
# --> 140     if _is_zip(str(filename)):
#     141         parsed = fiona.parse_path(str(filename))
#     142         if isinstance(parsed, fiona.path.ParsedPath):
# ...

# %%
study = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/3homes.json") #circles for 3 homes
vec = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/polygon_Concord_neighborhood_2017-2021.json") #block groups
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 study = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/3homes.json") #circles for 3 homes
#       2 vec = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/polygon_Concord_neighborhood_2017-2021.json")
#
# File /opt/miniconda3/envs/geovis/lib/python3.11/site-packages/geopandas/io/file.py:140, in _read_file(filename, bbox, mask, rows, **kwargs)
#     135     reader = fiona.BytesCollection
#     136 else:
#     137     # Opening a file via URL or file-like-object above automatically detects a
#     138     # zipped file. In order to match that behavior, attempt to add a zip scheme
#     139     # if missing.
# --> 140     if _is_zip(str(filename)):
#     141         parsed = fiona.parse_path(str(filename))
#     142         if isinstance(parsed, fiona.path.ParsedPath):
# ...

# %%
study = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/3homes.json") #circles for 3 homes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 study = gpd.read_file("/Users/bhoconnor/Documents/GitHub/Data/Lab4/3homes.json")
#
# File /opt/miniconda3/envs/geovis/lib/python3.11/site-packages/geopandas/io/file.py:140, in _read_file(filename, bbox, mask, rows, **kwargs)
#     135     reader = fiona.BytesCollection
#     136 else:
#     137     # Opening a file via URL or file-like-object above automatically detects a
#     138     # zipped file. In order to match that behavior, attempt to add a zip scheme
#     139     # if missing.
# --> 140     if _is_zip(str(filename)):
#     141         parsed = fiona.parse_path(str(filename))
#     142         if isinstance(parsed, fiona.path.ParsedPath):
#     143             # If fiona is able to parse the path, we can safely look at the scheme
# ...
